# %%
from matplotlib import pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.scatter(x, y)
plt.title('Gráfico de dispersión de prueba')
# Out:
# Text(0.5, 1.0, 'Gráfico de dispersión de prueba')

# %% [markdown]
# Esta es una celda Markdown
